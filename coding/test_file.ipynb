# %%
import cProfile


def lange_berechnung():
    # Simulierte lange Berechnung
    summe = 0
    for i in range(1000000):
        summe += i
    return summe


cProfile.run('lange_berechnung()')
# Out:
#          350 function calls in 0.049 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.006    0.006    0.006    0.006 3749640795.py:4(lange_berechnung)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.026    0.026 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#         1    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         1    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         1    0.000    0.000    0.007    0.007 base_events.py:1909(_run_once)
#         4    0.000    0.000    0.000    0.000 base_events.py:2004(get_debug)
#         2    0.000    0.000    0.000    0.000 base_events.py:539(_check_closed)
# ...
